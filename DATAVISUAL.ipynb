# %% [markdown]
# <a href="https://colab.research.google.com/github/Taro489/Tugas_IndividuBigData/blob/master/DATAVISUAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA VISUALIZING

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://www-eu.apache.org/dist/spark/spark-2.4.6/spark-2.4.6-bin-hadoop2.7.tgz
# !tar xf spark-2.4.6-bin-hadoop2.7.tgz
# !pip install -q findspark
# !pip install -q pyspark_dist_explore

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.6-bin-hadoop2.7"

# %%
import findspark
findspark.init("spark-2.4.6-bin-hadoop2.7")# SPARK_HOME
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
from pyspark.sql.functions import *
import matplotlib.pyplot as plt
from pyspark_dist_explore import Histogram, hist

# %%
from collections import Counter
import pandas as pd
import seaborn as sn
import numpy as np
import csv

# %%
font = {'family': 'serif',
        'color':  'Red',
        'weight': 'normal',
        'size': 16,
        }

# %%
font1 = {'family': 'serif',
        'color':  'green',
        'weight': 'normal',
        'size': 18,
        }

# %%
font2 = {'family': 'serif',
        'color':  'Black',
        'weight': 'normal',
        'size': 18,
        }

# %%
x = []
y = []

with open('/content/df1.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2010', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df2.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2011', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df3.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2012', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df4.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2013', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df5.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2014', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df6.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2015', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df7.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2016', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df8.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2017', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df9.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2018', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = []
y = []

with open('/content/df10.csv', 'r') as csvfile:
  plots = csv.reader(csvfile, delimiter=',')
  for row in plots:
        x.append(row[0])
        y.append(row[1])

# %%
plt.bar(x, y)
plt.xticks(rotation=90)
plt.xlabel('Genre', fontdict=font)
plt.ylabel('Jumlah genre', fontdict=font1)
plt.title('Top genre in Top 10 Music chart in 2019', fontdict=font2)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
